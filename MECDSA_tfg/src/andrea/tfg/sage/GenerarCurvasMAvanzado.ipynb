# %%
######################## PRIMERA CURVA ELÍPTICA ############################

print("#########################")
print("OPERACIONES PRIMERA CURVA")
print("#########################")
print
# Obtenemos los parámetros a, b y p de la primra curva a partir del fichero paramPrimeraCurva.txt que se genera
# en el programa principal.
with open('paramPrimeraCurva.txt', 'r') as f1:
    L1 = [(l1.strip()) for l1 in f1]
f1.close()

# Imprimimos el contenido del fichero para comprobar que son los parámetros insertados.
# Por orden tenemos a, b y p.
print("Imprimimos los parámetros obtenidos en java introducidos por el usuario.")
print(L1)
print

# Generamos la curva con los parámetros del txt.
p1 = int(L1[2])
prev_proof_state = proof.arithmetic()
proof.arithmetic(False)
F1 = GF(p1)                                       # Definimos el cuerpo.
a1 = int(L1[0])
b1 = int(L1[1])
E1 = EllipticCurve(F1,[a1,b1])                    # Aquí cremos la curva elíptica.
P1 = E1.random_element()                                   # P contiene la lista de puntos de la CE.

# Guardamos el orden de E en la variable n y el pto base.
n1 = E1.cardinality()

# Imprimimos el resultado para verificar que es correcto.
print("Obtenemos el orden de la curva.")
print(n1)
print
print("Obtenemos el punto base de la curva.")

# Obtenemos las coordenadas x e y del punto base.
x1 = P1[0]
y1 = P1[1]

# Creamos un nuevo fichero llamado ordenPtoBPrimeraCurva.txt que contiene el orden y el punto.
ficheroEsc1C = open('ordenPtoBPrimeraCurva.txt','w')
ficheroEsc1C.write(str(n1))
ficheroEsc1C.write("\n")
ficheroEsc1C.write(str(x1))
ficheroEsc1C.write("\n")
ficheroEsc1C.write(str(y1))
ficheroEsc1C.close()

# Abrimos el fichero creado anteriormente y verificamos que es correcto.
with open('ordenPtoBPrimeraCurva.txt', 'r') as f1:
    L1 = f1.read()
f1.close()
    
print
print("Imprimimos el contenido del fichero con el orden y las coordenadas del punto base.")
print(L1)
print


######################## SEGUNDA CURVA ELÍPTICA ############################

print("#########################")
print("OPERACIONES SEGUNDA CURVA")
print("#########################")
print
# Obtenemos los parámetros a, b y p de la segunda curva a partir del fichero paramPrimeraCurva.txt que se genera 
# en el programa principal.
with open('paramSegundaCurva.txt', 'r') as f2:
    L2 = [(l2.strip()) for l2 in f2]
f2.close()

# Imprimimos el contenido del fichero para comprobar que son los parámetros insertados.
# Por orden tenemos a, b y p.
print("Imprimimos los parámetros obtenidos en java introducidos por el usuario.")
print(L2)
print

# Generamos la curva con los parámetros del txt.
p2 = int(L2[2])
print("Imprimimos p de la curva.")
print(p2)
print
prev_proof_state = proof.arithmetic()
proof.arithmetic(False)
F2 = GF(p2)                                       # Definimos el cuerpo.
a2 = int(L2[0])
b2 = int(L2[1])
E2 = EllipticCurve(F2,[a2,b2])                    # Aquí cremos la curva elíptica.                                                  # P contiene la lista de puntos de la CE.
P2 = E2.random_element() 
print("Imprimimos el punto")
print(P2)
print
                                  

# Guardamos el orden de E en la variable n y el pto base.
n2 = E2.cardinality()


# Imprimimos el resultado para verificar que es correcto.
print("Obtenemos el orden de la curva.")
print(n2)
print

# Obtenemos las coordenadas x e y del punto base.
x2 = P2[0]
y2 = P2[1]

# Creamos un nuevo fichero llamado ordenPtoBPrimeraCurva.txt que contiene el orden y el punto.
ficheroEsc2C = open('ordenPtoBSegundaCurva.txt','w')
ficheroEsc2C.write(str(n2))
ficheroEsc2C.write("\n")
ficheroEsc2C.write(str(x2))
ficheroEsc2C.write("\n")
ficheroEsc2C.write(str(y2))
ficheroEsc2C.close()

# Abrimos el fichero creado anteriormente y verificamos que es correcto.
with open('ordenPtoBSegundaCurva.txt', 'r') as f2:
    L2 = f2.read()
f2.close()

print
print("Imprimimos el contenido del fichero con el orden y las coordenadas del punto base.")
print(L2)
# Out:
# #########################
# OPERACIONES PRIMERA CURVA
# #########################
#
# Imprimimos los parámetros obtenidos en java introducidos por el usuario.
# ['13', '-13', '23']
#
# Obtenemos el orden de la curva.
# 19
#
# Obtenemos el punto base de la curva.
#
# Imprimimos el contenido del fichero con el orden y las coordenadas del punto base.
# 19
# 19
# 20
#
# #########################
# OPERACIONES SEGUNDA CURVA
# #########################
#
# Imprimimos los parámetros obtenidos en java introducidos por el usuario.
# ['13', '-13', '23']
#
# Imprimimos p de la curva.
# 23
#
# Imprimimos el punto
# (11 : 9 : 1)
#
# Obtenemos el orden de la curva.
# 19
#
#
# Imprimimos el contenido del fichero con el orden y las coordenadas del punto base.
# 19
# 11
# 9
